# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

df = pd.read_csv("../data/train-full.csv")
print("data loaded")

counts = Counter(df["landmark_id"])
x = counts.keys()
y = counts.values()
print("data counted")

# outdf = pd.DataFrame({'x': x, 'y': y})
# outdf.to_csv('../data/histogram.csv')
# Out:
# data loaded
# data counted

# %%
histogram = Counter(y)

# %%
histogram = histogram.most_common(len(histogram))

# %%
xx = [tup[0] for tup in histogram]
yy = [tup[1] for tup in histogram]

# %%
plt.scatter(np.log(xx), np.log(yy), s=2, color='g')
plt.xlabel("Number of Examples per Class (log)")
plt.ylabel("Number of Landmarks with Class Size x (log)")
plt.title("Distribution of Class Sizes")
# Out:
# Text(0.5, 1.0, 'Distribution of Class Sizes')

# %%
import numpy as np
plt.scatter(x, np.log(np.array(list(y))), s=.4)
plt.xlabel("Landmark ID")
plt.ylabel("Number of Examples per Class (log)")
plt.title("Examples per Landmark")
plt.show()
